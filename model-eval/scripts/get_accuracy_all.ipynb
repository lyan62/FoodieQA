# %%
import utils, sivqa_utils
import os 
import json
from sklearn.metrics import accuracy_score
import re
import random
import glob

# %% [markdown]
# # Sivqa evaluation

# %%
# Load data
result_dir = "../../dataset/sivqa_res"
sivqa = sivqa_utils.read_sivqa("../../dataset/")
gts_t = [s["answer"] for s in sivqa]
# question_ids = [s["question_id"] for s in sivqa]
food_type = [s["food_meta"].get("food_type") for s in sivqa]
question_type = [s.get("question_type") for s in sivqa]

# food_type

# %%
# Count the number of questions in each question type
print("Count the number of questions in each question type")
for q_type in set(question_type):
    print(q_type, question_type.count(q_type))

# Dictionary to store indices for each question type
question_type_indices = {qtype: [] for qtype in ["present", "cooking-skills", "main-ingredient", "flavor", "region-2", "cuisine_type"]}

# Populate the dictionary with indices
for i, t in enumerate(question_type):
    if t in question_type_indices:
        question_type_indices[t].append(i)

# Prepare the final data list
question_type_data = [(qtype, indices) for qtype, indices in question_type_indices.items()]

# # Use the indices individually
# present_indices = question_type_indices["present"]
# cooking_skills_indices = question_type_indices["cooking-skills"]
# main_ingredient_indices = question_type_indices["main-ingredient"]
# flavor_indices = question_type_indices["flavor"]
# region_indices = question_type_indices["region-2"]
# cuisine_type_indices = question_type_indices["cuisine_type"]

# print(present_indices)
# Out:
# Count the number of questions in each question type
# flavor 46
# present 14
# region-2 65
# cooking-skills 51
# main-ingredient 10
# cuisine_type 70

# %%
# Count the number of questions in each food type
print("Count the number of questions in each question type")
for f_type in set(food_type):
    print(f_type, food_type.count(f_type))

# Move "内蒙菜","北京菜","云南菜" to "其他"
food_type_indices = {}
food_type_list = ['上海菜', '浙菜（浙江）','粤菜（广东等地）','湘菜（湖南）','其他','新疆菜', '东北菜 （黑龙江等地）','闽菜（福建）', 
                  '西北菜 （陕西，甘肃等地）', '客家菜',  '徽菜 （安徽）','黔菜 (贵州）',  '川菜（四川，重庆）', '苏菜（江苏）',
                  "内蒙菜 （内蒙古）", "北京菜", "云南菜","上海本帮菜"]
for f_type in food_type_list:
    if food_type.count(f_type) <= 2:
        food_type_indices["其他"] = [i for i, f in enumerate(food_type) if food_type.count(f) <= 2]
    else:
        if "上海" in f_type:
            food_type_indices["上海菜"] = [i for i, f in enumerate(food_type) if "上海" in f]
        else:
            food_type_indices[f_type] = [i for i, f in enumerate(food_type) if f == f_type]

# # Prepare the final data list
food_type_data = [(ftype, indices) for ftype, indices in food_type_indices.items()]
print(food_type_indices.keys())
# Out:
# Count the number of questions in each question type
# 黔菜 (贵州） 16
# 闽菜（福建） 11
# 新疆菜 25
# 上海本帮菜 5
# 苏菜（江苏） 33
# 粤菜（广东等地） 37
# 客家菜 7
# 上海菜 7
# 内蒙菜 （内蒙古） 1
# 北京菜 1
# 湘菜（湖南） 10
# 东北菜 （黑龙江等地） 9
# 川菜（四川，重庆） 47
# 西北菜 （陕西，甘肃等地） 25
# 徽菜 （安徽） 4
# 浙菜（浙江） 16
# 云南菜 2
# dict_keys(['上海菜', '浙菜（浙江）', '粤菜（广东等地）', '湘菜（湖南）', '其他', '新疆菜', '东北菜 （黑龙江等地）', '闽菜（福建）', '西北菜 （陕西，甘肃等地）', '客家菜', '徽菜 （安徽）', '黔菜 (贵州）', '川菜（四川，重庆）', '苏菜（江苏）'])

# %%
ans2idx = {
        "A":"0",
        "B":"1",
        "C":"2",
        "D":"3"
        }

def parse_common(ans_str):
    """
    Common parsing logic to extract and validate the answer from the string.
    """
    random.seed(42)
    ans_letter = re.findall(r'[A-Z]', ans_str)
    if not ans_letter or len(ans_letter) == 0:
        print("Cannot parse answer for response string:", ans_str)
        return random.choice(["0", "1", "2", "3"])
    else:
        ans = ans_letter[0].upper()
        if ans not in ans2idx:
            print("Cannot parse answer for response string:", ans_str)
            return random.choice(["0", "1", "2", "3"])
        else:
            return ans2idx[ans]

def parse_res(res):
    ans_str = res["response"][0].split("\nAssistant:")[-1].strip()
    return parse_common(ans_str)

def parse_qwen(res, template=0):
    if template in [0, 1, 3]:
        ans_str = res["response"].split("选择一个正确答案")[1].strip()
    else:
        ans_str = ""  # Adjust as needed for other templates
    return parse_common(ans_str)

def parse_yi(res, template=0):
    ans_str = res["response"].strip()
    return parse_common(ans_str)

def parse_phi(res):
    random.seed(42)
    ans_str = res["response"]
    return parse_common(ans_str)
        
def read_res_data(res_file):
    data = []
    # "sivqa_mantis_prompt3.jsonl"
    with open(os.path.join(result_dir, res_file), "r", encoding='utf-8') as f:
        for line in f:
            data.append(json.loads(line))
    return data
        
def get_accuracy_all(ans_data, parse_fn=parse_res, analysis_labels=None):
    def compute_accuracy(indices, label):
        subset_gts = [gts_t[i] for i in indices]
        subset_answers = [answers[i] for i in indices]
        accuracy = accuracy_score(subset_gts, subset_answers)
        # print(f"{label}:", accuracy)
        # print(f"{label}")
        print(accuracy)
    
    # Get all ground truths and parsed answers
    # gts = [s["answer"] for s in sivqa]
    random.seed(42)
    answers = [parse_fn(d) for d in ans_data]
    
    # Overall accuracy
    compute_accuracy(range(len(gts_t)), "All questions")
    
    if analysis_labels is not None:
        for mark, mark_idx in analysis_labels:
            compute_accuracy(mark_idx, mark)

def get_accuracy(sivqa, data, parse_fn=parse_res): 
    # get acc
    random.seed(42)
    gts = [s["answer"] for s in sivqa]
    answers = [parse_fn(d) for d in data]
    accuracy = accuracy_score(gts, answers)
    print(accuracy)

def get_eval_results(ans_files, parser=parse_res, analysis_category=None):
    for file in sorted(ans_files):
        file_name = os.path.basename(file)
        print(file_name)
        # load data
        ans_data = read_res_data(file_name)       
        get_accuracy_all(ans_data, parse_fn=parser, analysis_labels=analysis_category)
        # get_accuracy(sivqa, data)

        print("-"*25)

# %% [markdown]
# ## Mantis

# %%
mantis_res_files = glob.glob(os.path.join(result_dir, "sivqa_mantis_prompt*.jsonl"))
print(sorted(mantis_res_files))
# print(sorted(mantis_res_files)[:4])
# get_eval_results(sorted(mantis_res_files)[:4], parser=parse_res, analysis_category=question_type_data)
get_eval_results(mantis_res_files[:4], parser=parse_res, analysis_category=food_type_data)
# print(sorted(mantis_res_files)[4:])
# Out:
# ['../../dataset/sivqa_res/sivqa_mantis_prompt0.jsonl', '../../dataset/sivqa_res/sivqa_mantis_prompt1.jsonl', '../../dataset/sivqa_res/sivqa_mantis_prompt2.jsonl', '../../dataset/sivqa_res/sivqa_mantis_prompt3.jsonl']
# sivqa_mantis_prompt0.jsonl
# 0.40234375
# 0.3333333333333333
# 0.5
# 0.4594594594594595
# 0.2
# 0.25
# 0.36
# 0.2222222222222222
# 0.5454545454545454
# 0.12
# 0.7142857142857143
# 0.25
# 0.3125
# 0.574468085106383
# 0.3939393939393939
# -------------------------
# sivqa_mantis_prompt1.jsonl
# 0.41796875
# 0.4166666666666667
# 0.5
# 0.40540540540540543
# 0.3
# 0.5
# 0.44
# 0.2222222222222222
# 0.45454545454545453
# 0.24
# 0.5714285714285714
# 0.25
# 0.3125
# 0.574468085106383
# 0.3939393939393939
# -------------------------
# sivqa_mantis_prompt2.jsonl
# 0.41796875
# 0.3333333333333333
# 0.5
# 0.4594594594594595
# 0.2
# 0.25
# 0.4
# 0.2222222222222222
# 0.45454545454545453
# 0.28
# 0.7142857142857143
# 0.0
# 0.3125
# 0.5957446808510638
# 0.3939393939393939
# -------------------------
# sivqa_mantis_prompt3.jsonl
# 0.40234375
# 0.3333333333333333
# 0.5
# 0.43243243243243246
# 0.3
# 0.5
# 0.32
# 0.2222222222222222
# 0.45454545454545453
# 0.16
# 0.7142857142857143
# 0.25
# 0.3125
# 0.574468085106383
# 0.3939393939393939
# -------------------------

# %% [markdown]
# ## Idefics

# %%
idefics_res_files = glob.glob(os.path.join(result_dir, "sivqa_idefics*.jsonl"))
print(sorted(idefics_res_files))
# get_eval_results(sorted(idefics_res_files)[:4], parser=parse_res, analysis_category=question_type_data)
get_eval_results(sorted(idefics_res_files)[:4], parser=parse_res, analysis_category=food_type_data)
# Out:
# ['../../dataset/sivqa_res/sivqa_idefics_prompt0.jsonl', '../../dataset/sivqa_res/sivqa_idefics_prompt1.jsonl', '../../dataset/sivqa_res/sivqa_idefics_prompt2.jsonl', '../../dataset/sivqa_res/sivqa_idefics_prompt3.jsonl', '../../dataset/sivqa_res/sivqa_idefics_prompt4.jsonl']
# sivqa_idefics_prompt0.jsonl
# Cannot parse answer for response string: 川渝.
# Cannot parse answer for response string: 煮.
# Cannot parse answer for response string: 煮.
# 0.44921875
# 0.4166666666666667
# 0.5
# 0.5675675675675675
# 0.3
# 0.75
# 0.52
# 0.3333333333333333
# 0.36363636363636365
# 0.32
# 0.7142857142857143
# 0.0
# 0.1875
# 0.6170212765957447
# 0.30303030303030304
# -------------------------
# sivqa_idefics_prompt1.jsonl
# Cannot parse answer for response string: 煎.
# Cannot parse answer for response string: 炸.
# Cannot parse answer for response string: 炒.
# Cannot parse answer for response string: 炒.
# Cannot parse answer for response string: 炒.
# 0.4453125
# 0.5833333333333334
# 0.4375
# 0.5945945945945946
# 0.4
# 0.75
# 0.36
# 0.3333333333333333
# 0.2727272727272727
# 0.28
# 0.7142857142857143
# 0.0
# 0.1875
# 0.6382978723404256
# 0.3333333333333333
# -------------------------
# sivqa_idefics_prompt2.jsonl
# Cannot parse answer for response string: 客家菜).
# Cannot parse answer for response string: Sichuan.
# Cannot parse answer for response string: 客家菜).
# 0.4609375
# 0.4166666666666667
# 0.4375
# 0.5675675675675675
# 0.3
# 0.75
# 0.44
# 0.3333333333333333
# 0.36363636363636365
# 0.32
# 0.7142857142857143
# 0.0
# 0.25
# 0.6595744680851063
# 0.3939393939393939
# -------------------------
# sivqa_idefics_prompt3.jsonl
# Cannot parse answer for response string: 客家菜).
# 0.46875
# 0.4166666666666667
# 0.5625
# 0.5405405405405406
# 0.4
# 0.75
# 0.48
# 0.3333333333333333
# 0.36363636363636365
# 0.36
# 0.7142857142857143
# 0.25
# 0.1875
# 0.6382978723404256
# 0.36363636363636365
# -------------------------

# %% [markdown]
# ## Qwen

# %%
qwen_res_files = glob.glob(os.path.join(result_dir, "sivqa_qwen_prompt*.jsonl"))
print(sorted(qwen_res_files))
# get_eval_results(sorted(qwen_res_files)[:4], parser=parse_qwen, analysis_category=question_type_data)
get_eval_results(sorted(qwen_res_files)[:4], parser=parse_qwen, analysis_category=food_type_data)
# Out:
# ['../../dataset/sivqa_res/sivqa_qwen_prompt0.jsonl', '../../dataset/sivqa_res/sivqa_qwen_prompt1.jsonl', '../../dataset/sivqa_res/sivqa_qwen_prompt2.jsonl', '../../dataset/sivqa_res/sivqa_qwen_prompt3.jsonl', '../../dataset/sivqa_res/sivqa_qwen_prompt4.jsonl']
# sivqa_qwen_prompt0.jsonl
# 0.44140625
# 0.5
# 0.4375
# 0.3783783783783784
# 0.5
# 0.5
# 0.44
# 0.5555555555555556
# 0.45454545454545453
# 0.48
# 0.14285714285714285
# 0.0
# 0.375
# 0.5957446808510638
# 0.3333333333333333
# -------------------------
# sivqa_qwen_prompt1.jsonl
# 0.40234375
# 0.5
# 0.375
# 0.40540540540540543
# 0.5
# 0.5
# 0.6
# 0.3333333333333333
# 0.36363636363636365
# 0.36
# 0.42857142857142855
# 0.0
# 0.125
# 0.5319148936170213
# 0.24242424242424243
# -------------------------
# sivqa_qwen_prompt2.jsonl
# 0.48828125
# 0.4166666666666667
# 0.375
# 0.5135135135135135
# 0.8
# 0.75
# 0.44
# 0.5555555555555556
# 0.2727272727272727
# 0.52
# 0.5714285714285714
# 0.0
# 0.3125
# 0.7446808510638298
# 0.24242424242424243
# -------------------------
# sivqa_qwen_prompt3.jsonl
# 0.41796875
# 0.5
# 0.3125
# 0.5135135135135135
# 0.7
# 0.5
# 0.32
# 0.5555555555555556
# 0.36363636363636365
# 0.36
# 0.14285714285714285
# 0.0
# 0.3125
# 0.5531914893617021
# 0.30303030303030304
# -------------------------

# %% [markdown]
# ## Yi

# %%
yi_res_files = glob.glob(os.path.join(result_dir, "sivqa_yi*.jsonl"))
print(sorted(yi_res_files))
# get_eval_results(sorted(yi_res_files)[:4], parser=parse_yi, analysis_category=question_type_data)
get_eval_results(sorted(yi_res_files)[:4], parser=parse_yi, analysis_category=food_type_data)
# Out:
# ['../../dataset/sivqa_res/sivqa_yi-vl_prompt0.jsonl', '../../dataset/sivqa_res/sivqa_yi-vl_prompt1.jsonl', '../../dataset/sivqa_res/sivqa_yi-vl_prompt2.jsonl', '../../dataset/sivqa_res/sivqa_yi-vl_prompt3.jsonl', '../../dataset/sivqa_res/sivqa_yi-vl_prompt4.jsonl']
# sivqa_yi-vl_prompt0.jsonl
# 0.49609375
# 0.3333333333333333
# 0.5625
# 0.7837837837837838
# 0.4
# 0.75
# 0.36
# 0.4444444444444444
# 0.36363636363636365
# 0.32
# 0.7142857142857143
# 0.25
# 0.375
# 0.6382978723404256
# 0.3333333333333333
# -------------------------
# sivqa_yi-vl_prompt1.jsonl
# 0.48046875
# 0.3333333333333333
# 0.5625
# 0.7837837837837838
# 0.4
# 0.5
# 0.48
# 0.4444444444444444
# 0.2727272727272727
# 0.32
# 0.5714285714285714
# 0.0
# 0.4375
# 0.5531914893617021
# 0.3333333333333333
# -------------------------
# sivqa_yi-vl_prompt2.jsonl
# 0.4765625
# 0.3333333333333333
# 0.5
# 0.7297297297297297
# 0.4
# 0.5
# 0.52
# 0.4444444444444444
# 0.2727272727272727
# 0.32
# 0.42857142857142855
# 0.0
# 0.4375
# 0.5957446808510638
# 0.3333333333333333
# -------------------------
# sivqa_yi-vl_prompt3.jsonl
# Cannot parse answer for response string: 京菜
# Cannot parse answer for response string: 徽菜
# Cannot parse answer for response string: 宁波
# Cannot parse answer for response string: 广东
# Cannot parse answer for response string: 客家
# Cannot parse answer for response string: 川渝
# Cannot parse answer for response string: 东北
# Cannot parse answer for response string: 南方
# Cannot parse answer for response string: 台州
# Cannot parse answer for response string: 贵州
# Cannot parse answer for response string: 粤菜
# Cannot parse answer for response string: 四川
# Cannot parse answer for response string: 川菜
# Cannot parse answer for response string: 粤
# Cannot parse answer for response string: 川菜
# Cannot parse answer for response string: 川菜
# Cannot parse answer for response string: 蒸
# Cannot parse answer for response string: 浙江
# Cannot parse answer for response string: 新疆
# Cannot parse answer for response string: 粤
# Cannot parse answer for response string: 川菜
# Cannot parse answer for response string: 错误
# Cannot parse answer for response string: 客家菜
# Cannot parse answer for response string: 川菜
# Cannot parse answer for response string: 客家菜
# Cannot parse answer for response string: 湖南
# Cannot parse answer for response string: 广东
# Cannot parse answer for response string: 潮汕菜
# Cannot parse answer for response string: 东北菜
# Cannot parse answer for response string: 蒸
# Cannot parse answer for response string: 重庆
# Cannot parse answer for response string: 东北菜
# Cannot parse answer for response string: 福建
# Cannot parse answer for response string: 川菜
# Cannot parse answer for response string: 双层铜锅
# Cannot parse answer for response string: 北京
# 0.44921875
# 0.3333333333333333
# 0.5625
# 0.6756756756756757
# 0.4
# 0.75
# 0.36
# 0.3333333333333333
# 0.18181818181818182
# 0.4
# 0.42857142857142855
# 0.0
# 0.375
# 0.5319148936170213
# 0.36363636363636365
# -------------------------

# %% [markdown]
# ## Yi-34B

# %%
yi_34b_res_files = glob.glob(os.path.join(result_dir, "sivqa_Yi*.jsonl"))
print(sorted(yi_34b_res_files))
# get_eval_results(sorted(yi_34b_res_files)[:4], parser=parse_yi, analysis_category=question_type_data)
get_eval_results(sorted(yi_34b_res_files)[:4], parser=parse_yi, analysis_category=food_type_data)
# Out:
# ['../../dataset/sivqa_res/sivqa_Yi-VL-34B_prompt0.jsonl', '../../dataset/sivqa_res/sivqa_Yi-VL-34B_prompt1.jsonl', '../../dataset/sivqa_res/sivqa_Yi-VL-34B_prompt2.jsonl', '../../dataset/sivqa_res/sivqa_Yi-VL-34B_prompt3.jsonl']
# sivqa_Yi-VL-34B_prompt0.jsonl
# 0.50390625
# 0.5
# 0.25
# 0.7837837837837838
# 0.4
# 1.0
# 0.4
# 0.4444444444444444
# 0.36363636363636365
# 0.36
# 0.5714285714285714
# 0.25
# 0.25
# 0.6808510638297872
# 0.42424242424242425
# -------------------------
# sivqa_Yi-VL-34B_prompt1.jsonl
# 0.52734375
# 0.5833333333333334
# 0.3125
# 0.8108108108108109
# 0.4
# 0.75
# 0.48
# 0.4444444444444444
# 0.2727272727272727
# 0.32
# 0.5714285714285714
# 0.25
# 0.25
# 0.7021276595744681
# 0.5151515151515151
# -------------------------
# sivqa_Yi-VL-34B_prompt2.jsonl
# Cannot parse answer for response string: 蒸
# Cannot parse answer for response string: 这个图片描绘了充满各种食物的碗,包括许多小豆子,可能还有一些蔬菜。根据视觉提示,这碗食物看起来更接近于苏菜或沪菜,因为这两道菜都以其独特的烹饪风格和口味而闻名。
# Cannot parse answer for response string: 这个图片显示的是苏菜。
# Cannot parse answer for response string: 这个图片展示了一个美味的甜点,上面有水果和酱油,放在一张纸上。
# Cannot parse answer for response string: 这个图片显示了一个碗牛肉面,它通常属于中国菜,特别是粤菜。
# Cannot parse answer for response string: 东北菜
# 0.50390625
# 0.5
# 0.3125
# 0.7297297297297297
# 0.5
# 0.75
# 0.44
# 0.3333333333333333
# 0.2727272727272727
# 0.32
# 0.7142857142857143
# 0.25
# 0.25
# 0.6382978723404256
# 0.5454545454545454
# -------------------------
# sivqa_Yi-VL-34B_prompt3.jsonl
# Cannot parse answer for response string: 这个图片显示了一个白色的盘子,上面放着一块土豆,上面放着一些草药。
# 0.48828125
# 0.5
# 0.1875
# 0.8378378378378378
# 0.5
# 0.75
# 0.44
# 0.4444444444444444
# 0.2727272727272727
# 0.28
# 0.5714285714285714
# 0.25
# 0.25
# 0.6382978723404256
# 0.3939393939393939
# -------------------------

# %% [markdown]
# ## Phi-3

# %%
phi_3_res_files = glob.glob(os.path.join(result_dir, "sivqa_Phi*.jsonl"))
print(sorted(phi_3_res_files))
# get_eval_results(sorted(yi_34b_res_files)[:4], parser=parse_yi, analysis_category=question_type_data)
get_eval_results(sorted(phi_3_res_files)[:4], parser=parse_phi, analysis_category=food_type_data)
# Out:
# ['../../dataset/sivqa_res/sivqa_Phi-3-vision-128k-instruct_zh_prompt0.jsonl', '../../dataset/sivqa_res/sivqa_Phi-3-vision-128k-instruct_zh_prompt1.jsonl', '../../dataset/sivqa_res/sivqa_Phi-3-vision-128k-instruct_zh_prompt2.jsonl', '../../dataset/sivqa_res/sivqa_Phi-3-vision-128k-instruct_zh_prompt3.jsonl']
# sivqa_Phi-3-vision-128k-instruct_zh_prompt0.jsonl
# Cannot parse answer for response string:
#
#
# Cannot parse answer for response string:
#
#
# Cannot parse answer for response string: 潮汕
# 0.42578125
# 0.25
# 0.1875
# 0.4594594594594595
# 0.5
# 0.5
# 0.4
# 0.4444444444444444
# 0.36363636363636365
# 0.4
# 0.42857142857142855
# 0.25
# 0.4375
# 0.6382978723404256
# 0.30303030303030304
# -------------------------
# sivqa_Phi-3-vision-128k-instruct_zh_prompt1.jsonl
# Cannot parse answer for response string:
#
#
#
# 0.41796875
# 0.3333333333333333
# 0.25
# 0.5405405405405406
# 0.5
# 0.5
# 0.4
# 0.3333333333333333
# 0.2727272727272727
# 0.32
# 0.42857142857142855
# 0.25
# 0.3125
# 0.6170212765957447
# 0.30303030303030304
# -------------------------
# sivqa_Phi-3-vision-128k-instruct_zh_prompt2.jsonl
# Cannot parse answer for response string: 香港
# Cannot parse answer for response string: 赣菜
# Cannot parse answer for response string: 西北菜
# Cannot parse answer for response string: 北京
# Cannot parse answer for response string: 赣菜
# Cannot parse answer for response string: 南京
# Cannot parse answer for response string: 湖南
# Cannot parse answer for response string: 内蒙古
# Cannot parse answer for response string: 四川
# Cannot parse answer for response string: 烟台
# Cannot parse answer for response string: 浙江
# Cannot parse answer for response string: 西宁
# Cannot parse answer for response string: 四川
# Cannot parse answer for response string: 粤菜
# Cannot parse answer for response string: 四川
# Cannot parse answer for response string: 四川
# Cannot parse answer for response string: 西安
# Cannot parse answer for response string: 咸辣
# Cannot parse answer for response string: 潮汕
# Cannot parse answer for response string: 西安
# Cannot parse answer for response string: 北京
# Cannot parse answer for response string: 杭州
# 0.390625
# 0.25
# 0.25
# 0.5135135135135135
# 0.5
# 0.5
# 0.4
# 0.3333333333333333
# 0.18181818181818182
# 0.28
# 0.42857142857142855
# 0.25
# 0.3125
# 0.5106382978723404
# 0.36363636363636365
# -------------------------
# sivqa_Phi-3-vision-128k-instruct_zh_prompt3.jsonl
# Cannot parse answer for response string: （
# Cannot parse answer for response string: 选项（
# Cannot parse answer for response string:
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: 西北菜
# Cannot parse answer for response string: 北京
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string:
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string:
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: 北京
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: 北京
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: 内蒙古
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: 四川
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string:
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string:
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: 四川
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string:
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: 四川
# Cannot parse answer for response string: 四川
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: 西安
# Cannot parse answer for response string: （
# Cannot parse answer for response string:
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string:
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: 潮汕
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string:
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: 北京
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string: （
# Cannot parse answer for response string:
# 0.34375
# 0.4166666666666667
# 0.3125
# 0.2702702702702703
# 0.5
# 0.5
# 0.28
# 0.4444444444444444
# 0.5454545454545454
# 0.32
# 0.14285714285714285
# 0.25
# 0.4375
# 0.3829787234042553
# 0.2727272727272727
# -------------------------

# %% [markdown]
# # MIVQA accuracy

# %%
# result_dir = "/Users/wli/projects/foodie-dataset/data/results/mivqa_res"
result_dir = "../../dataset/mivqa_res"
mivqa = utils.read_mivqa("../../dataset/", "mivqa_filtered.json")

# %%
gts_t = [s["answer"] for s in mivqa]
# question_ids = [s["question_id"] for s in sivqa]
ann_type = [s["ann_group"] for s in mivqa]
question_type = [s.get("question_type") for s in mivqa]

# %%
# Count the number of questions in each question type
print("Count the number of questions in each question type")
for q_type in set(question_type):
    print(q_type, question_type.count(q_type))
print(len(set(question_type)))

# Dictionary to store indices for each question type
# Move "expense","smell","history" into "other"
mi_questions_type = ["color", "cooking-skills", "ingredients", "allergy", "region", "taste", "food-type", "eating-habit", "plating","amount","other"]
question_type_indices = {qtype: [] for qtype in mi_questions_type}
# print(mi_questions_type)

# Populate the dictionary with indices
for i, t in enumerate(question_type):
    if t in question_type_indices:
        question_type_indices[t].append(i)
    else:
        # print(t)
        question_type_indices["other"].append(i)

# Prepare the final data list
question_type_data = [(qtype, indices) for qtype, indices in question_type_indices.items()]
# print(question_type_data[-1])
# # Use the indices individually
# present_indices = question_type_indices["present"]
# cooking_skills_indices = question_type_indices["cooking-skills"]
# main_ingredient_indices = question_type_indices["main-ingredient"]
# flavor_indices = question_type_indices["flavor"]
# region_indices = question_type_indices["region-2"]
# cuisine_type_indices = question_type_indices["cuisine_type"]

# print(present_indices)
# Out:
# Count the number of questions in each question type
# taste 50
# smell 1
# expense 1
# other 2
# cooking-skills 45
# food-type 60
# region 15
# color 36
# eating-habit 27
# allergy 12
# ingredients 119
# history 1
# amount 11
# plating 23
# 14

# %%
# Count the number of questions in each ann type
print("Count the number of questions in each question type")
for a_type in set(ann_type):
    print(a_type, ann_type.count(a_type))
# print(len(set(ann_type)))

# Dictionary to store indices for each ann type
mi_ann_type = ['main-noodle',
 'tofu',
 '上海',
 'meat',
 '黔',
 '西北',
 '新疆',
 'main-bao',
 'bbq',
 'main-soup',
 '湘',
 '闽',
 '其他',
 '川',
 '内蒙.赣.徽',
 '浙',
 '苏',
 '粤',
 'main-hotpot',
 'snack',
 'seafood',
 '东北']
ann_type_indices = {qtype: [] for qtype in mi_ann_type}
# print(mi_questions_type)

# Populate the dictionary with indices
for i, t in enumerate(ann_type):
    if t in ann_type_indices:
        ann_type_indices[t].append(i)

# Prepare the final data list
ann_type_data = [(atype, indices) for atype, indices in ann_type_indices.items()]
# print(question_type_data[-1])
# # Use the indices individually
# present_indices = question_type_indices["present"]
# cooking_skills_indices = question_type_indices["cooking-skills"]
# main_ingredient_indices = question_type_indices["main-ingredient"]
# flavor_indices = question_type_indices["flavor"]
# region_indices = question_type_indices["region-2"]
# cuisine_type_indices = question_type_indices["cuisine_type"]

# print(present_indices)
# ann_type_data
# Out:
# Count the number of questions in each question type
# 浙 19
# main-bao 5
# main-hotpot 11
# 粤 37
# 川 39
# 湘 10
# 东北 1
# main-soup 7
# 西北 26
# 闽 14
# 内蒙.赣.徽 6
# 黔 13
# meat 43
# 上海 17
# 新疆 12
# main-noodle 40
# 苏 25
# snack 9
# seafood 37
# 其他 19
# tofu 8
# bbq 5

# %%
mi_mantis_files = glob.glob(os.path.join(result_dir, "mivqa_mantis*.jsonl"))
print(sorted(mi_mantis_files))

# get_eval_results(sorted(mi_mantis_files)[:4], parser=utils.parse_mantis, analysis_category=question_type_data)
get_eval_results(sorted(mi_mantis_files)[:4], parser=utils.parse_mantis, analysis_category=ann_type_data)
# Out:
# ['../../dataset/mivqa_res/mivqa_mantis_prompt0.jsonl', '../../dataset/mivqa_res/mivqa_mantis_prompt1.jsonl', '../../dataset/mivqa_res/mivqa_mantis_prompt2.jsonl', '../../dataset/mivqa_res/mivqa_mantis_prompt3.jsonl']
# mivqa_mantis_prompt0.jsonl
# 0.4665012406947891
# 0.4
# 0.625
# 0.47058823529411764
# 0.4186046511627907
# 0.3076923076923077
# 0.46153846153846156
# 0.4166666666666667
# 0.6
# 0.8
# 0.5714285714285714
# 0.3
# 0.5
# 0.6842105263157895
# 0.358974358974359
# 0.3333333333333333
# 0.631578947368421
# 0.48
# 0.5135135135135135
# 0.36363636363636365
# 0.2222222222222222
# 0.5675675675675675
# 0.0
# -------------------------
# mivqa_mantis_prompt1.jsonl
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# 0.2555831265508685
# 0.175
# 0.375
# 0.4117647058823529
# 0.32558139534883723
# 0.3076923076923077
# 0.3076923076923077
# 0.25
# 0.0
# 0.6
# 0.2857142857142857
# 0.1
# 0.14285714285714285
# 0.10526315789473684
# 0.28205128205128205
# 0.16666666666666666
# 0.10526315789473684
# 0.4
# 0.21621621621621623
# 0.45454545454545453
# 0.1111111111111111
# 0.24324324324324326
# 0.0
# -------------------------
# mivqa_mantis_prompt2.jsonl
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# Can not parse response, falling back to random...
# 0.3771712158808933
# 0.325
# 0.25
# 0.29411764705882354
# 0.4186046511627907
# 0.23076923076923078
# 0.5
# 0.5
# 0.2
# 1.0
# 0.5714285714285714
# 0.2
# 0.2857142857142857
# 0.47368421052631576
# 0.3333333333333333
# 0.0
# 0.3684210526315789
# 0.32
# 0.4594594594594595
# 0.18181818181818182
# 0.3333333333333333
# 0.43243243243243246
# 1.0
# -------------------------
# mivqa_mantis_prompt3.jsonl
# 0.2704714640198511
# 0.325
# 0.5
# 0.4117647058823529
# 0.18604651162790697
# 0.15384615384615385
# 0.23076923076923078
# 0.16666666666666666
# 0.2
# 0.6
# 0.0
# 0.4
# 0.42857142857142855
# 0.47368421052631576
# 0.20512820512820512
# 0.3333333333333333
# 0.05263157894736842
# 0.32
# 0.2972972972972973
# 0.36363636363636365
# 0.4444444444444444
# 0.16216216216216217
# 0.0
# -------------------------

# %%
mi_idefics2_files = glob.glob(os.path.join(result_dir, "mivqa_idefics*.jsonl"))
print(sorted(mi_idefics2_files))

# get_eval_results(sorted(mi_idefics2_files)[:4], parser=utils.parse_idefics, analysis_category=question_type_data)
get_eval_results(sorted(mi_idefics2_files)[:4], parser=utils.parse_idefics, analysis_category=ann_type_data)
# Out:
# ['../../dataset/mivqa_res/mivqa_idefics2-8b_prompt0.jsonl', '../../dataset/mivqa_res/mivqa_idefics2-8b_prompt1.jsonl', '../../dataset/mivqa_res/mivqa_idefics2-8b_prompt2.jsonl', '../../dataset/mivqa_res/mivqa_idefics2-8b_prompt3.jsonl']
# mivqa_idefics2-8b_prompt0.jsonl
# 0.3598014888337469
# 0.325
# 0.0
# 0.47058823529411764
# 0.3488372093023256
# 0.46153846153846156
# 0.4230769230769231
# 0.3333333333333333
# 0.2
# 0.4
# 0.42857142857142855
# 0.4
# 0.42857142857142855
# 0.3684210526315789
# 0.3333333333333333
# 0.3333333333333333
# 0.3684210526315789
# 0.36
# 0.35135135135135137
# 0.2727272727272727
# 0.3333333333333333
# 0.40540540540540543
# 0.0
# -------------------------
# mivqa_idefics2-8b_prompt1.jsonl
# 0.49379652605459057
# 0.6
# 0.375
# 0.35294117647058826
# 0.4418604651162791
# 0.6153846153846154
# 0.5
# 0.5833333333333334
# 0.2
# 0.8
# 0.7142857142857143
# 0.6
# 0.42857142857142855
# 0.3684210526315789
# 0.46153846153846156
# 0.3333333333333333
# 0.5263157894736842
# 0.48
# 0.5405405405405406
# 0.36363636363636365
# 0.4444444444444444
# 0.5405405405405406
# 0.0
# -------------------------
# mivqa_idefics2-8b_prompt2.jsonl
# 0.5086848635235732
# 0.5
# 0.25
# 0.35294117647058826
# 0.4883720930232558
# 0.5384615384615384
# 0.5
# 0.75
# 0.0
# 0.8
# 0.7142857142857143
# 0.6
# 0.5
# 0.5789473684210527
# 0.46153846153846156
# 0.6666666666666666
# 0.631578947368421
# 0.44
# 0.5135135135135135
# 0.45454545454545453
# 0.3333333333333333
# 0.5945945945945946
# 0.0
# -------------------------
# mivqa_idefics2-8b_prompt3.jsonl
# 0.4044665012406948
# 0.3
# 0.375
# 0.4117647058823529
# 0.3953488372093023
# 0.46153846153846156
# 0.46153846153846156
# 0.25
# 0.6
# 0.4
# 0.7142857142857143
# 0.3
# 0.5
# 0.3684210526315789
# 0.358974358974359
# 0.5
# 0.5789473684210527
# 0.44
# 0.43243243243243246
# 0.2727272727272727
# 0.3333333333333333
# 0.40540540540540543
# 0.0
# -------------------------

# %%
mi_qwen_files = glob.glob(os.path.join(result_dir, "mivqa_qwen*.jsonl"))
print(sorted(mi_qwen_files))

# get_eval_results(sorted(mi_qwen_files)[:4], parser=utils.parse_qwen, analysis_category=question_type_data)
get_eval_results(sorted(mi_qwen_files)[:4], parser=utils.parse_qwen, analysis_category=ann_type_data)
# Out:
# ['../../dataset/mivqa_res/mivqa_qwen_temp0.jsonl', '../../dataset/mivqa_res/mivqa_qwen_temp1.jsonl', '../../dataset/mivqa_res/mivqa_qwen_temp2.jsonl', '../../dataset/mivqa_res/mivqa_qwen_temp3.jsonl']
# mivqa_qwen_temp0.jsonl
# 0.2555831265508685
# 0.275
# 0.25
# 0.058823529411764705
# 0.2558139534883721
# 0.23076923076923078
# 0.3076923076923077
# 0.25
# 0.2
# 0.2
# 0.2857142857142857
# 0.3
# 0.42857142857142855
# 0.21052631578947367
# 0.38461538461538464
# 0.3333333333333333
# 0.2631578947368421
# 0.24
# 0.21621621621621623
# 0.18181818181818182
# 0.3333333333333333
# 0.16216216216216217
# 0.0
# -------------------------
# mivqa_qwen_temp1.jsonl
# 0.27543424317617865
# 0.3
# 0.125
# 0.29411764705882354
# 0.3023255813953488
# 0.23076923076923078
# 0.19230769230769232
# 0.3333333333333333
# 0.4
# 0.0
# 0.42857142857142855
# 0.3
# 0.2857142857142857
# 0.10526315789473684
# 0.38461538461538464
# 0.3333333333333333
# 0.3157894736842105
# 0.24
# 0.2702702702702703
# 0.2727272727272727
# 0.4444444444444444
# 0.21621621621621623
# 0.0
# -------------------------
# mivqa_qwen_temp2.jsonl
# 0.3052109181141439
# 0.225
# 0.125
# 0.35294117647058826
# 0.3023255813953488
# 0.23076923076923078
# 0.38461538461538464
# 0.25
# 0.4
# 0.2
# 0.42857142857142855
# 0.2
# 0.21428571428571427
# 0.42105263157894735
# 0.4358974358974359
# 0.3333333333333333
# 0.3157894736842105
# 0.16
# 0.2972972972972973
# 0.09090909090909091
# 0.5555555555555556
# 0.35135135135135137
# 0.0
# -------------------------
# mivqa_qwen_temp3.jsonl
# 0.2630272952853598
# 0.25
# 0.375
# 0.17647058823529413
# 0.20930232558139536
# 0.3076923076923077
# 0.34615384615384615
# 0.5
# 0.2
# 0.0
# 0.14285714285714285
# 0.2
# 0.2857142857142857
# 0.3157894736842105
# 0.358974358974359
# 0.16666666666666666
# 0.15789473684210525
# 0.28
# 0.24324324324324326
# 0.2727272727272727
# 0.1111111111111111
# 0.2702702702702703
# 0.0
# -------------------------

# %%
mi_phi_files = glob.glob(os.path.join(result_dir, "mivqa_Phi*.jsonl"))
print(sorted(mi_phi_files))

get_eval_results(sorted(mi_phi_files)[:4], parser=parse_phi, analysis_category=question_type_data)
# get_eval_results(sorted(mi_phi_files)[:4], parser=parse_phi, analysis_category=ann_type_data)
# Out:
# ['../../dataset/mivqa_res/mivqa_Phi-3-vision-128k-instruct_prompt0.jsonl', '../../dataset/mivqa_res/mivqa_Phi-3-vision-128k-instruct_prompt1.jsonl', '../../dataset/mivqa_res/mivqa_Phi-3-vision-128k-instruct_prompt2.jsonl', '../../dataset/mivqa_res/mivqa_Phi-3-vision-128k-instruct_prompt3.jsonl']
# mivqa_Phi-3-vision-128k-instruct_prompt0.jsonl
# 0.26054590570719605
# 0.2777777777777778
# 0.28888888888888886
# 0.2605042016806723
# 0.3333333333333333
# 0.2
# 0.22
# 0.3
# 0.2222222222222222
# 0.08695652173913043
# 0.5454545454545454
# 0.2
# -------------------------
# mivqa_Phi-3-vision-128k-instruct_prompt1.jsonl
# Cannot parse answer for response string: 根据以上四张图，以上需要放入囊坑烤制的是：答案为：烤制的。
# 0.2903225806451613
# 0.3055555555555556
# 0.37777777777777777
# 0.23529411764705882
# 0.25
# 0.26666666666666666
# 0.22
# 0.45
# 0.18518518518518517
# 0.21739130434782608
# 0.45454545454545453
# 0.2
# -------------------------
# mivqa_Phi-3-vision-128k-instruct_prompt2.jsonl
# Cannot parse answer for response string: 菜品中，通常使用蒸制方法烹饪的是菜肴。
# Cannot parse answer for response string: 题目：下列哪道菜是河鲜？答案为：图。
#
# 题目：下列哪道菜是河鲜？答案为：图。
#
# 题目：下列哪道菜是河鲜？答案为：图。
#
# 题目：下列哪道菜是河鲜？答案为：图。
#
# 题目：下列哪道菜是河鲜？答案为：图。
#
# 题目：下列哪道菜是河鲜？答案为：图。
#
# 题目：下列哪道菜是河鲜？答案为：图。
#
# 题目：下列哪道菜是河鲜？答案为：图。
#
# 题目：下列哪道菜是河鲜？答案为：图。
#
# 题目：下列哪道菜是河鲜？答案为：图。
#
# 题目：下列哪道菜是河鲜？答案为：图。
#
# 题目：下列哪道菜是河鲜？答案为：图。
#
# 题目：下列哪道菜是河鲜？答案为：图。
#
# 题目：下列哪道菜是河鲜？答案为：图。
#
# 题目：下列哪道菜是河鲜？答案为：图。
#
# 题目：下列哪道菜是河鲜？答案为：图。
#
# 题目：下列哪道菜是河鲜？答案为：图。
#
# 题目：下列哪道菜是河鲜？答案为
# Cannot parse answer for response string: 菜
# Cannot parse answer for response string: 菜
# Cannot parse answer for response string: 菜
# 0.2655086848635236
# 0.25
# 0.3333333333333333
# 0.2605042016806723
# 0.25
# 0.26666666666666666
# 0.26
# 0.2833333333333333
# 0.2222222222222222
# 0.13043478260869565
# 0.45454545454545453
# 0.2
# -------------------------
# mivqa_Phi-3-vision-128k-instruct_prompt3.jsonl
# Cannot parse answer for response string:
#
# 图
# Cannot parse answer for response string:
#
# 图
# Cannot parse answer for response string:
#
# 图
# Cannot parse answer for response string:
#
# 问题：这个菜肴是哪个？
# Cannot parse answer for response string:
#
# 图
# Cannot parse answer for response string:
#
# 问题如果你喜欢吃海鲜，你回答以下问题：
#
# 1. 你最喜欢吃的海鲜是什么？
# 2. 你最喜欢的海鲜的味道是什么？
# 3. 你最喜欢的海鲜的风味是什么？
# 4. 你最喜欢的海鲜的风味是什么？
# 5. 你最喜欢的海鲜的风味是什么？
# 6. 你最喜欢的海鲜的风味是什么？
# 7. 你最喜欢的海鲜的风味是什么？
# 8. 你最喜欢的海鲜的风味是什么？
# 9. 你最喜欢的海鲜的风味是什么？
# 10. 你最喜欢的海鲜的风味是什么？
# 11. 你最喜欢的海鲜的风味是什么？
# 12. 你最喜欢的海鲜的风味是什么？
# 13. 你最喜欢的海鲜的风味是什么？
# 14. 你最喜欢的海鲜的风味是什么？
# 15. 你最喜欢的海鲜的风味是什么？
# 16. 你最喜欢的海鲜的风味是什么？
# 17. 你最喜欢的海鲜的����
# Cannot parse answer for response string:
#
# 问题：在以下四张图片中，哪个菜品的烹饪方法更加精准，哪个菜品的烹饪方法更加浓厚，哪个菜品的烹饪方法更加浓厚，哪个菜品的烹饪方法更加精准，哪个菜品的烹饪方法更加浓厚，哪个菜品的烹饪方法更加精准，哪个菜品的烹饪方法更加浓厚，哪个菜品的烹饪方法更加精准，哪个菜品的烹饪方法更加浓厚，哪个菜品的烹饪方法更加精准，哪个菜品的烹饪方法更加浓厚，哪个菜品的烹饪方法更加精准，哪个菜品的烹饪方法更加浓厚，哪个菜品的烹饪方法更加精准，哪个菜品的烹饪方法更加浓厚，哪个菜品的烹饪方法更加精准，哪个菜品的烹饪方法更加浓厚，哪个菜品的烹饪方法更加精准，哪个菜品的烹饪方法更加浓厚，哪个菜品的烹饪方法更加精准，哪个菜品
# Cannot parse answer for response string:
#
# 图
# Cannot parse answer for response string:
#
# 图
# Cannot parse answer for response string:
#
# 问题：在以下四个选项中，哪个选项中的句子更具有含蓄的意义？
# 选项有：
#
# 1. 我很抱歉，我的朋友刚才在吃饭了。
# 2. 我很抱歉，我的朋友刚才在吃饭了。
# 3. 我很抱歉，我的朋友刚才在吃饭了。
# 4. 我很抱歉，我的朋友刚才在吃饭了。
#
# 选项1、2、3、4中，哪个选项中的句子更具有含蓄的意义？
#
# 选项1、2、3、4中，哪个选项中的句子更具有含蓄的意义？
#
# 选项1、2、3、4中，哪个选项中的句子更具有含蓄的意义？
#
# 选项1、2、3、4中，哪个选项中的句子更具有含蓄的意义？
#
# 选项1、2、3、4中，哪个选项中的句子更具有含蓄的意义？
#
# 选项1、2、3、4中，哪个选项中的句子更具有含蓄的意义？
#
# 选项1、2、3、4中，哪个选项中的句子更具有含蓄的意义？
#
# 选项1、2、3、4中，哪个选项中的句
# Cannot parse answer for response string:
#
# 图
# Cannot parse answer for response string:
#
# 图
# Cannot parse answer for response string:
#
# 问题：在以下四个选项中，哪个选项中的句子更具有含蓄的意义？
#
# 选项有：
#
# 1. 我很抱歉，我的朋友刚才听到了这个抱怨的话。
# 2. 我很抱歉，我的朋友刚才听到了这个抱怨的话。
# 3. 我很抱歉，我的朋友刚才听到了这个抱怨的话。
# 4. 我很抱歉，我的朋友刚才听到了这个抱怨的话。
#
# 选项1、选项2、选项3、选项4。
#
#
# 选项1、选项2、选项3、选项4。
#
#
# 问题：以下句子中哪个更具有含蓄的意义？
#
# 选项有：
#
# 1. 我很抱歉，我的朋友刚才听到了这个抱怨的话。
# 2. 我很抱歉，我的朋友刚才听到了这个抱怨的话。
# 3. 我很抱歉，我的朋友刚才听到了这个抱怨的话。
# 4. 我很抱歉，我的朋友刚才听到了这个抱怨的话。
#
# 选项1、选项2、选项3、选项4。
#
#
# 问题：以下句子中哪个更具有����
# Cannot parse answer for response string:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Cannot parse answer for response string:
#
# 问题：这个菜肴的名字是什么？
# Cannot parse answer for response string:
#
# 图
# Cannot parse answer for response string:
#
# 图
# Cannot parse answer for response string:
#
# 图
# Cannot parse answer for response string:
#
# 问题：这个菜肴的名字是什么？
#
# 问题：这个菜肴的味道如何？
#
# 问题：这个菜肴的风味如何？
#
# 问题：这个菜肴的饮用方式如何？
#
# 问题：这个菜肴的历史背景如何？
#
# 问题：这个菜肴的制作过程如何？
#
# 问题：这个菜肴的饮用地点如何？
#
# 问题：这个菜肴的健康价值如何？
#
# 问题：这个菜肴的成分如何？
#
# 问题：这个菜肴的风味如何？
#
# 问题：这个菜肴的饮用方式如何？
#
# 问题：这个菜肴的风味如何？
#
# 问题：这个菜肴的饮用方式如何？
#
# 问题：这个菜肴的风味如何？
#
# 问题：这个菜肴的饮用方式如何？
#
# 问题：这个菜肴的风味如何？
#
# 问题：这个菜肴的饮用方式如何？
#
# 问题：这个菜肴的风味如何？
#
# 问题：这个菜肴的饮用方式如何？
#
# 问题：这个菜肴的风味如何？
#
# 问题：这个菜肴的饮用方式如何？
#
# 问题：这个菜肴的风味如何？
#
# 问题：这个菜肴的饮用方式如何？
#
# 问题：这个菜肴的风味如何？
#
# 问
# 0.2679900744416873
# 0.1111111111111111
# 0.08888888888888889
# 0.31932773109243695
# 0.4166666666666667
# 0.4
# 0.28
# 0.3
# 0.3333333333333333
# 0.21739130434782608
# 0.18181818181818182
# 0.6
# -------------------------

# %%
mi_qwen_files = glob.glob(os.path.join(result_dir, "mivqa_qwen_*.jsonl"))
print(sorted(mi_qwen_files))

for file in sorted(mi_qwen_files):
    file_name = os.path.basename(file)
    print(file_name)
    # load data
    data = read_res_data(file_name)        
    get_accuracy(mivqa, data, parse_fn=utils.parse_qwen)
# Out:
# ['../../dataset/mivqa_res/mivqa_qwen_temp0.jsonl', '../../dataset/mivqa_res/mivqa_qwen_temp1.jsonl', '../../dataset/mivqa_res/mivqa_qwen_temp2.jsonl', '../../dataset/mivqa_res/mivqa_qwen_temp3.jsonl']
# mivqa_qwen_temp0.jsonl
# 0.2555831265508685
# mivqa_qwen_temp1.jsonl
# 0.27543424317617865
# mivqa_qwen_temp2.jsonl
# 0.3052109181141439
# mivqa_qwen_temp3.jsonl
# 0.2630272952853598
