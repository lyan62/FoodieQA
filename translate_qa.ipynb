# %%
from transformers import M2M100ForConditionalGeneration, M2M100Tokenizer

import transformers
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-zh-en")
model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-zh-en")
# Out:
# /scratch3/wenyan/miniconda3/envs/yi/lib/python3.10/site-packages/transformers/models/marian/tokenization_marian.py:197: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
import pandas as pd
df = pd.read_csv("/scratch3/wenyan/data/foodie/QA.csv")
df.head()
# Out:
#   Question type                           Question     Choices Answer  \
# 0        binary              东坡肉和苏式红烧肉其中哪一个口感更为软糯？   东坡肉/苏式红烧肉    东坡肉
# 1        binary  东坡肉和苏式红烧肉哪一个的起源和名字跟中国宋代的一位文人墨客有关？   东坡肉/苏式红烧肉    东坡肉
# 2        binary                  东坡肉和苏式红烧肉哪一个属于浙菜？   东坡肉/苏式红烧肉    东坡肉
# 3        binary          毛氏红烧肉和东坡肉，其中哪一道菜需要使用砂锅制作？   毛氏红烧肉/东坡肉    东坡肉
# 4        binary        潮汕火锅和北京铜锅涮羊肉，其中哪一道菜通常配麻酱蘸碟？  潮汕火锅/铜锅涮羊肉  铜锅涮羊肉
#
#   Relevant cuisines  Image-ids related-meta-field reference Annotation  \
# 0         苏式红烧肉/东坡肉        NaN                 口味       NaN     wenyan
# 1         苏式红烧肉/东坡肉        NaN           菜系/地域/文化       NaN     wenyan
# 2         苏式红烧肉/东坡肉        NaN              菜系/地域       NaN     wenyan
# 3         毛氏红烧肉/东坡肉        NaN               制作工具       NaN     wenyan
# 4        潮汕火锅/铜锅涮羊肉        NaN                NaN       NaN        NaN
#
#    Verification  Rational
# 0           NaN       NaN
# 1           NaN       NaN
# 2           NaN       NaN
# 3           NaN       NaN
# 4           NaN       NaN

# %%
text ='央视春晚，没有最烂，只有更烂'

# translate Chinese to English
for i in range(10):
    chinese_text = df.iloc[i]["Question"]
    print(chinese_text)
    tokenizer.src_lang = "zh"
    encoded_zh = tokenizer(chinese_text, return_tensors="pt")
    generated_tokens = model.generate(**encoded_zh)
    print(tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0])
    print("\n")
# => "Life is like a box of chocolate."
# Out:
# 东坡肉和苏式红烧肉其中哪一个口感更为软糯？
# Which one of the East Poe and Su red meats has a softer taste?
#
#
# 东坡肉和苏式红烧肉哪一个的起源和名字跟中国宋代的一位文人墨客有关？
# Which of the origins and names of the East Po and Su red meat are related to a human ink in Song-dee, China?
#
#
# 东坡肉和苏式红烧肉哪一个属于浙菜？
# Which one of the East Poe and Su red meats is a pickle?
#
#
# 毛氏红烧肉和东坡肉，其中哪一道菜需要使用砂锅制作？
# Which one of them needs to be made with casseroles?
#
#
# 潮汕火锅和北京铜锅涮羊肉，其中哪一道菜通常配麻酱蘸碟？
# The tidal pot and the bronze cauldron of Beijing, which one of these foods is usually with a sauce sauce saucer?
#
#
# 糖醋排骨属于以下哪一个菜系？
# Which one of the following is the sugar-fried ribs?
#
#
# 以下哪一道菜更辣？
# Which one of these is more hot?
#
#
# 其中哪一种肉属于湘菜？
# Which kind of meat is a pickle?
#
#
# 四川红烧肉，毛式红烧肉和东坡肉中，对于一个不能吃辣的人，你更推荐哪道菜？
# Which dish do you recommend to a man who can't eat hot meat in Sichuan red meat, hairy red meat and East Poe meat?
#
#
# 梅菜扣肉和香芋扣肉有什么区别？
# What's the difference between casserole and casserole?
